# %% [markdown]
# <a href="https://colab.research.google.com/github/Maranatha2025/EJERCICIOS_POO_3_TRIMESTRE/blob/main/dataclasses_import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from dataclasses import dataclass

@dataclass
class Libro:
    _titulo: str
    _autor: str
    _isbn: str
    _precio: float

    @property
    def titulo(self) -> str:
        return self._titulo

    @property
    def autor(self) -> str:
        return self._autor

    @property
    def isbn(self) -> str:
        return self._isbn

    @property
    def precio(self) -> float:
        return self._precio

    @titulo.setter
    def titulo(self, valor: str) -> None:
        if isinstance(valor, str) and valor.strip():
            self._titulo = valor
        else:
            raise ValueError("El título debe ser un texto válido no vacío.")

    @autor.setter
    def autor(self, valor: str) -> None:
        if isinstance(valor, str) and valor.strip():
            self._autor = valor
        else:
            raise ValueError("El autor debe ser un texto válido no vacío.")

    @isbn.setter
    def isbn(self, valor: str) -> None:
        if isinstance(valor, str) and valor.strip():
            self._isbn = valor
        else:
            raise ValueError("El ISBN debe ser un texto válido no vacío.")

    @precio.setter
    def precio(self, valor: float) -> None:
        if isinstance(valor, (int, float)) and valor > 0:
            self._precio = float(valor)
        else:
            raise ValueError("El precio debe ser un número positivo.")

    def __repr__(self) -> str:
        return (
            f"Libro(titulo='{self._titulo}', autor='{self._autor}', "
            f"isbn='{self._isbn}', precio={self._precio})"
        )


def main() -> None:
    libro = Libro("python senior IA", "pedro perez", "123-456-789", 1200000)

    print("\n=== INFORMACIÓN LIBRO ===")
    print(libro)

    libro.precio = 150000
    libro.titulo = "python avanzado 3.0"

    print("\n=== DATOS ACTUALIZADOS ===")
    print(libro)

    libro.isbn = "444444444"

    print("\n=== DATOS ACTUALIZADOS ===")
    print(libro)


if __name__ == "__main__":
    main()
# Out:
# === INFORMACIÓN LIBRO ===
# Libro(titulo='python senior IA', autor='pedro perez', isbn='123-456-789', precio=1200000)
#
# === DATOS ACTUALIZADOS ===
# Libro(titulo='python avanzado 3.0', autor='pedro perez', isbn='123-456-789', precio=150000.0)
#
# === DATOS ACTUALIZADOS ===
# Libro(titulo='python avanzado 3.0', autor='pedro perez', isbn='444444444', precio=150000.0)
