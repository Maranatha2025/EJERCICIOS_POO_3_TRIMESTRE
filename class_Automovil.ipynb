# %% [markdown]
# <a href="https://colab.research.google.com/github/Maranatha2025/EJERCICIOS_POO_3_TRIMESTRE/blob/main/class_Automovil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Automovil:   #clase (es como los planos)
  def __init__(self, marca, modelo, color):   #constructor
    self.marca = marca    #atributos
    self.modelo = modelo
    self.color = color
  def mostrar__info(self):   #metodos
    print(f"La marca del vehiculo es: {self.marca}")
    print(f"El modelo del vehiculo es: {self.modelo}")
    print(f"El color del vehiculo es: {self.color}")

  def main():
    marca = input("La marca del vehiculo es: ")
    modelo = input("El modelo del vehiculo es: ")
    color = input("El color del vehiculo es: ")
  if __name__ == "__main__":
      main()
# Out:
# La marca del vehiculo es: BMW
# El modelo del vehiculo es: mazda
# El color del vehiculo es: verde
