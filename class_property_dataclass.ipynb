# %% [markdown]
# <a href="https://colab.research.google.com/github/Maranatha2025/EJERCICIOS_POO_3_TRIMESTRE/blob/main/class_property_dataclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from dataclasses import dataclass: es como un archivo e importa los datos de la libreria
from dataclasses import dataclass

@dataclass    # decorador
class Libro:
    _titulo: str
    _autor: str
    _isbn: str
    _precio: float

    @property        # reemplaza el Getters (muestra)
    def titulo(self) -> str:
        return self._titulo

    @property        # reemplaza el Getters (muestra)
    def autor(self) -> str:
        return self._autor

    @property        # reemplaza el Getters (muestra)
    def isbn(self) -> str:
        return self._isbn

    @property        # reemplaza el Getters (muestra)
    def precio(self) -> float:
        return self._precio

    @titulo.setter    # modifica
    def titulo(self, valor: str) -> None:
        if isinstance(valor, str) and valor.strip():
            self._titulo = valor
        else:
            raise ValueError("El título debe ser un texto válido no vacío.")

    @autor.setter    # modifica
    def autor(self, valor: str) -> None:
        if isinstance(valor, str) and valor.strip():
            self._autor = valor
        else:
            raise ValueError("El autor debe ser un texto válido no vacío.")

    @isbn.setter    # modifica
    def isbn(self, valor: str) -> None:
        if isinstance(valor, str) and valor.strip():
            self._isbn = valor
        else:
            raise ValueError("El ISBN debe ser un texto válido no vacío.")

    @precio.setter    # modifica
    def precio(self, valor: float) -> None:
        if isinstance(valor, (int, float)) and valor > 0:
            self._precio = valor
        else:
            raise ValueError("El precio debe ser un numero positivo.")

    def __repr__(self) -> str:
        """Representación clara del objeto Libro."""
        return (
            f"Libro(título='{self._titulo}', autor='{self._autor}', "
            f"ISBN='{self._isbn}', precio={self._precio})"
        )


def main() -> None:
    my_libro = Libro("El Quijote", "Miguel de Cervantes", "978-3-16-148410-0", 19.99)

    print("\nInformación del libro:")
    print(my_libro)

    # Actualizamos el precio utilizando el setter
    my_libro.precio = 24.99
    my_libro.titulo = "Don Quijote de la Mancha"  # Actualizamos el título utilizando el setter

    print("\nInformación actualizada del libro:")
    print(my_libro)


if __name__ == "__main__":
    main()
# Out:
# Información del libro:
# Libro(título='El Quijote', autor='Miguel de Cervantes', ISBN='978-3-16-148410-0', precio=19.99)
#
# Información actualizada del libro:
# Libro(título='Don Quijote de la Mancha', autor='Miguel de Cervantes', ISBN='978-3-16-148410-0', precio=24.99)
