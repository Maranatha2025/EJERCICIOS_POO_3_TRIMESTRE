# %% [markdown]
# <a href="https://colab.research.google.com/github/Maranatha2025/EJERCICIOS_POO_3_TRIMESTRE/blob/main/Herencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HERENCIA: permite crear una clase nueva (subclase) a parti de otra (superclase) que es la clase principal, la subclase reutiliza los atributos y metodos de la superclase

#la clase PADRE es una clase base que contiene atributos o comportamiento comunes
#la clase HIJA hereda los comportamientos puede agregar o modificar lo que necesite

# crear clase Padre
class Vehiculo:
  def mover(self):
    print("El vehiculo se esta moviendo")



# crear clases hijas
class Carro(Vehiculo):  #hereda el metodo mover de la clase Padre del vehiculo
      pass

class Moto(Vehiculo):
      pass


def main():
  #creare mi primer OBJETO clase Padre
  print("Aqui muestro el metodo de la clase padre")
  vehiculo1 = Vehiculo()
  vehiculo1.mover()


  #creare mi primer OBJETO clase hijo
  print("\nLa clase hijo repetira el metodo mover () de la clase padre")
  carro1 = Carro()
  carro1.mover()

  #creare mi segundo OBJETO clase hijo
  print("\nLa clase hijo repetira el metodo mover () de la clase padre")
  moto1 = Moto()
  moto1.mover()




if __name__ == "__main__":
  main()
# Out:
# Aqui muestro el metodo de la clase padre
# El vehiculo se esta moviendo
#
# La clase hijo repetira el metodo mover () de la clase padre
# El vehiculo se esta moviendo
#
# La clase hijo repetira el metodo mover () de la clase padre
# El vehiculo se esta moviendo

# %%
#sobre escribir un metodo

class Vehiculo():
  def mover(self):
    print("El vehiculo se esta moviendo \n")


class Carro(Vehiculo):   #sobreescribo el metodo mover
  def mover(self):
    print("El CARRO se esta moviendo \n")


  def main():
    Vehiculo1 = Vehiculo()
    Vehiculo1.mover()

 #Aqui nos muestra el sobreescrito de mover() para el OBJETO carro1

    carro1 = Carro()
    carro1.mover()


  if __name__ == "__main__":
      main()
# Out:
# El vehiculo se esta moviendo
#
# El CARRO se esta moviendo

# %%
class Vehiculo():
  def mover(self):
    print("El vehiculo se esta moviendo \n")


class Barco(Vehiculo):   #sobreescribo el metodo mover
  def mover(self):
    print("El CARRO se esta moviendo \n")


  def main():
    Vehiculo1 = Vehiculo()
    Vehiculo1.mover()

 #Aqui nos muestra el sobreescrito de mover() para el OBJETO carro1

    carro1 = Carro()
    carro1.mover()


  if __name__ == "__main__":
      main()

# %%
class Vehiculo():

# %%
class Padre:
  def __init__(self, mensaje, color_ojos, tipo_sangre):
    self.mensaje = mensaje
    self.color_ojos = color_ojos
    self.tipo_sangre = tipo_sangre


class Hijo(Padre):
  def __init__(self, mensaje, color_ojos, tipo_sangre, nombre, genero, estatura):
    super().__init__(mensaje, color_ojos, tipo_sangre)  #llamo al constructor de la clase padre
    self.nombre = nombre
    self.genero = genero
    self.estatura = estatura


def main():
    obj = Hijo("Hola desde la clase Padre", "verdes", "O+", "Luis","Femenino", "1.59")  #instancia
    print(f"{obj.mensaje}, {obj.nombre} \n")
    print(obj.mensaje)
    print(obj.color_ojos)
    print(obj.tipo_sangre)


if __name__ == "__main__":
      main()
# Out:
#   File "/tmp/ipython-input-1213608289.py", line 17
#     obj = Hijo("Hola desde la clase Padre", "verdes", "O+", "Luis, "Femenino ")  #instancia
#                                                                              ^
# SyntaxError: unterminated string literal (detected at line 17)
